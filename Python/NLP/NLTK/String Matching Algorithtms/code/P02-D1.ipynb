# %%
import numpy as np

# %% [markdown]
# # Functions definitions

# %%
# %run "Functions_Defs.ipynb"

# %% [markdown]
# # Dataset 1
# ## Intra-Group

# %%
intra_Group_1 = {
    "pair_1": ["weight 1.3 length 2.7".split(), "weight 2.3 length 3.1".split()],
    "pair_2": ["weight 2.0 length 3.1".split(), "weight 1.3 length 2.7".split()],
    "pair_3": ["weight 1.3 length 1.3".split(), "weight 2.5 length 3.8".split()]
}

intra_Group_2 = {
    "pair_1": ["weight 6.6 length 6.2".split(), "weight 6.3 length 5.4".split()],
    "pair_2": ["weight 6.5 length 6.4".split(), "weight 6.6 length 6.0".split()],
    "pair_3": ["weight 6.3 length 5.8".split(), "weight 6.5 length 6.4".split()]
}

intra_Group_3 = {
    "pair_1": ["weight 9.5 length 9.9".split(), "weight 8.7 length 9.5".split()],
    "pair_2": ["weight 8.0 length 8.3".split(), "weight 9.7 length 9.9".split()],
    "pair_3": ["weight 8.9 length 8.9".split(), "weight 8.7 length 9.5".split()]
}

# %%
intra_Distances = {}
intra_Distances["MED_char"] = 0
intra_Distances["MED_word"] = 0
intra_Distances["EUC_char"] = 0
intra_Distances["EUC_word"] = 0
intra_Distances["MAN_char"] = 0
intra_Distances["MAN_word"] = 0
intra_Distances["CHB_char"] = 0
intra_Distances["CHB_word"] = 0
intra_Distances["COS_char"] = 0
intra_Distances["COS_word"] = 0
intra_Distances["JAC_char"] = 0
intra_Distances["JAC_word"] = 0
intra_Distances["JAC_bigram"] = 0
intra_Distances["Hamming"] = 0
intra_Distances["LCS_word"] = 0
intra_Distances["LCS_char"] = 0

# %% [markdown]
# ## Char base
# Minimum Edit Distance,
# Euclidean Distance, Manhattan Distance, Chebychev Distance, Cosine Similairty, bigram-level
# Jaccard Similarity, Hamming Distance

# %%
print("Intra Group (1)\n")

for i in intra_Group_1:
    print("Pair:\t\t\t\t",i)
    intra_Distances["MED_char"] += char_based(intra_Group_1[i][0], intra_Group_1[i][1])["total_MED"]
    intra_Distances["EUC_char"] += euclidean_distance(intra_Group_1[i][0], intra_Group_1[i][1], base = 'char', measure = 'freq')
    intra_Distances["MAN_char"] += manhattan_distance(intra_Group_1[i][0], intra_Group_1[i][1], base = 'char', measure = 'freq')
    intra_Distances["CHB_char"] += chebychev_distance(intra_Group_1[i][0], intra_Group_1[i][1], base = 'char', measure = 'freq')
    intra_Distances["COS_char"] += cosine_distance(intra_Group_1[i][0], intra_Group_1[i][1], base = 'char', measure = 'freq')
    intra_Distances["JAC_char"] += jaccard_distance(intra_Group_1[i][0], intra_Group_1[i][1], base = 'char')
    intra_Distances["Hamming"] += hamming_list_str_dist(intra_Group_1[i][0], intra_Group_1[i][1])
    intra_Distances["LCS_char"] += LCS(intra_Group_1[i][0], intra_Group_1[i][1], base = "char")["size"]
    
    print ("Minimum Edit Distance:\t\t", char_based(intra_Group_1[i][0], intra_Group_1[i][1])["total_MED"])
    print ("Euclidean Distance:\t\t", euclidean_distance(intra_Group_1[i][0], intra_Group_1[i][1], base = 'char', measure = 'freq'))
    print ("Manhattan Distance:\t\t", manhattan_distance(intra_Group_1[i][0], intra_Group_1[i][1], base = 'char', measure = 'freq'))
    print ("Chebychev Distance:\t\t", chebychev_distance(intra_Group_1[i][0], intra_Group_1[i][1], base = 'char', measure = 'freq'))
    print ("Cosine Similarity:\t\t", cosine_similarity(intra_Group_1[i][0], intra_Group_1[i][1], base = 'char', measure = 'freq'))
    print ("Cosine Distance:\t\t", cosine_distance(intra_Group_1[i][0], intra_Group_1[i][1], base = 'char', measure = 'freq'))
    print ("Jaccard Similarity:\t\t", jaccard_similarity(intra_Group_1[i][0], intra_Group_1[i][1], base = 'char'))
    print ("Jaccard Distance:\t\t", jaccard_distance(intra_Group_1[i][0], intra_Group_1[i][1], base = 'char'))
    print("Hamming Distance:\t\t", hamming_list_str_dist(intra_Group_1[i][0], intra_Group_1[i][1]))
    print ("Longest Common Subsequence:\t\t", LCS(intra_Group_1[i][0], intra_Group_1[i][1], base = 'char')["size"])
    print ("\n")

print("Intra Group (2)\n")

for i in intra_Group_2:
    print("Pair:\t\t\t\t",i)
    intra_Distances["MED_char"] += char_based(intra_Group_2[i][0], intra_Group_2[i][1])["total_MED"]
    intra_Distances["EUC_char"] += euclidean_distance(intra_Group_2[i][0], intra_Group_2[i][1], base = 'char', measure = 'freq')
    intra_Distances["MAN_char"] += manhattan_distance(intra_Group_2[i][0], intra_Group_2[i][1], base = 'char', measure = 'freq')
    intra_Distances["CHB_char"] += chebychev_distance(intra_Group_2[i][0], intra_Group_2[i][1], base = 'char', measure = 'freq')
    intra_Distances["COS_char"] += cosine_distance(intra_Group_2[i][0], intra_Group_2[i][1], base = 'char', measure = 'freq')
    intra_Distances["JAC_char"] += jaccard_distance(intra_Group_2[i][0], intra_Group_2[i][1], base = 'char')
    intra_Distances["Hamming"] += hamming_list_str_dist(intra_Group_2[i][0], intra_Group_2[i][1])
    intra_Distances["LCS_char"] += LCS(intra_Group_2[i][0], intra_Group_2[i][1], base = "char")["size"]
    
    print ("Minimum Edit Distance:\t\t", char_based(intra_Group_2[i][0], intra_Group_2[i][1])["total_MED"])
    print ("Euclidean Distance:\t\t", euclidean_distance(intra_Group_2[i][0], intra_Group_2[i][1], base = 'char', measure = 'freq'))
    print ("Manhattan Distance:\t\t", manhattan_distance(intra_Group_2[i][0], intra_Group_2[i][1], base = 'char', measure = 'freq'))
    print ("Chebychev Distance:\t\t", chebychev_distance(intra_Group_2[i][0], intra_Group_2[i][1], base = 'char', measure = 'freq'))
    print ("Cosine Similarity:\t\t", cosine_similarity(intra_Group_2[i][0], intra_Group_2[i][1], base = 'char', measure = 'freq'))
    print ("Cosine Distance:\t\t", cosine_distance(intra_Group_2[i][0], intra_Group_2[i][1], base = 'char', measure = 'freq'))
    print ("Jaccard Similarity:\t\t", jaccard_similarity(intra_Group_2[i][0], intra_Group_2[i][1], base = 'char'))
    print ("Jaccard Distance:\t\t", jaccard_distance(intra_Group_2[i][0], intra_Group_2[i][1], base = 'char'))
    print("Hamming Distance:\t\t", hamming_list_str_dist(intra_Group_2[i][0], intra_Group_2[i][1]))
    print ("Longest Common Subsequence:\t\t", LCS(intra_Group_2[i][0], intra_Group_2[i][1], base = 'char')["size"])
    print ("\n")
    
print("Intra Group (3)\n")

for i in intra_Group_3:
    print("Pair:\t\t\t\t",i)
    intra_Distances["MED_char"] += char_based(intra_Group_3[i][0], intra_Group_3[i][1])["total_MED"]
    intra_Distances["EUC_char"] += euclidean_distance(intra_Group_3[i][0], intra_Group_3[i][1], base = 'char', measure = 'freq')
    intra_Distances["MAN_char"] += manhattan_distance(intra_Group_3[i][0], intra_Group_3[i][1], base = 'char', measure = 'freq')
    intra_Distances["CHB_char"] += chebychev_distance(intra_Group_3[i][0], intra_Group_3[i][1], base = 'char', measure = 'freq')
    intra_Distances["COS_char"] += cosine_distance(intra_Group_3[i][0], intra_Group_3[i][1], base = 'char', measure = 'freq')
    intra_Distances["JAC_char"] += jaccard_distance(intra_Group_3[i][0], intra_Group_3[i][1], base = 'char')
    intra_Distances["Hamming"] += hamming_list_str_dist(intra_Group_3[i][0], intra_Group_3[i][1])
    intra_Distances["LCS_char"] += LCS(intra_Group_3[i][0], intra_Group_3[i][1], base = "char")["size"]
    
    print ("Minimum Edit Distance:\t\t", char_based(intra_Group_3[i][0], intra_Group_3[i][1])["total_MED"])
    print ("Euclidean Distance:\t\t", euclidean_distance(intra_Group_3[i][0], intra_Group_3[i][1], base = 'char', measure = 'freq'))
    print ("Manhattan Distance:\t\t", manhattan_distance(intra_Group_3[i][0], intra_Group_3[i][1], base = 'char', measure = 'freq'))
    print ("Chebychev Distance:\t\t", chebychev_distance(intra_Group_3[i][0], intra_Group_3[i][1], base = 'char', measure = 'freq'))
    print ("Cosine Similarity:\t\t", cosine_similarity(intra_Group_3[i][0], intra_Group_3[i][1], base = 'char', measure = 'freq'))
    print ("Cosine Distance:\t\t", cosine_distance(intra_Group_3[i][0], intra_Group_3[i][1], base = 'char', measure = 'freq'))
    print ("Jaccard Similarity:\t\t", jaccard_similarity(intra_Group_3[i][0], intra_Group_3[i][1], base = 'char'))
    print ("Jaccard Distance:\t\t", jaccard_distance(intra_Group_3[i][0], intra_Group_3[i][1], base = 'char'))
    print("Hamming Distance:\t\t", hamming_list_str_dist(intra_Group_3[i][0], intra_Group_3[i][1]))
    print ("Longest Common Subsequence:\t\t", LCS(intra_Group_3[i][0], intra_Group_3[i][1], base = 'char')["size"])
    print ("\n")
# Out:
# Intra Group (1)
#
# Pair:				 pair_1
# Minimum Edit Distance:		 6
# Euclidean Distance:		 0.3535533905932738
# Manhattan Distance:		 0.5
# Chebychev Distance:		 0.25
# Cosine Similarity:		 0.9660917830792958
# Cosine Distance:		 0.033908216920704226
# Jaccard Similarity:		 0.9230769230769231
# Jaccard Distance:		 0.07692307692307687
# Hamming Distance:		 3
# Longest Common Subsequence:		 15
#
#
# Pair:				 pair_3
# Minimum Edit Distance:		 8
# Euclidean Distance:		 0.7071067811865476
# Manhattan Distance:		 1.5
# Chebychev Distance:		 0.5
# Cosine Similarity:		 0.8685990362153791
# Cosine Distance:		 0.13140096378462085
# Jaccard Similarity:		 0.7142857142857143
# Jaccard Distance:		 0.2857142857142857
# Hamming Distance:		 4
# Longest Common Subsequence:		 14
#
#
# Pair:				 pair_2
# Minimum Edit Distance:		 8
# Euclidean Distance:		 0.3535533905932738
# Manhattan Distance:		 0.5
# Chebychev Distance:		 0.25
# Cosine Similarity:		 0.9642857142857142
# ...

# %% [markdown]
# ## Word base
# Minimum Edit Distance,
# Euclidean Distance, Manhattan Distance, Chebychev Distance, Cosine Similairty, bigram-level
# Jaccard Similarity

# %%
print("Intra Group (1)\n")
for i in intra_Group_1:
    print("Pair:\t\t\t\t",i)
    intra_Distances["MED_word"] += word_based(intra_Group_1[i][0], intra_Group_1[i][1])["MED"]
    intra_Distances["EUC_word"] += euclidean_distance(intra_Group_1[i][0], intra_Group_1[i][1], base = 'word', measure = 'freq')
    intra_Distances["MAN_word"] += manhattan_distance(intra_Group_1[i][0], intra_Group_1[i][1], base = 'word', measure = 'freq')
    intra_Distances["CHB_word"] += chebychev_distance(intra_Group_1[i][0], intra_Group_1[i][1], base = 'word', measure = 'freq')
    intra_Distances["COS_word"] += cosine_distance(intra_Group_1[i][0], intra_Group_1[i][1], base = 'word', measure = 'freq')
    intra_Distances["JAC_word"] += jaccard_distance(intra_Group_1[i][0], intra_Group_1[i][1], base = 'word')
    intra_Distances["LCS_word"] += LCS(intra_Group_1[i][0], intra_Group_1[i][1], base = "word")["size"]
    
    print ("Minimum Edit Distance:\t\t", word_based(intra_Group_1[i][0], intra_Group_1[i][1])["MED"])
    print ("Euclidean Distance:\t\t", euclidean_distance(intra_Group_1[i][0], intra_Group_1[i][1], base = 'word', measure = 'freq'))
    print ("Manhattan Distance:\t\t", manhattan_distance(intra_Group_1[i][0], intra_Group_1[i][1], base = 'word', measure = 'freq'))
    print ("Chebychev Distance:\t\t", chebychev_distance(intra_Group_1[i][0], intra_Group_1[i][1], base = 'word', measure = 'freq'))
    print ("Cosine Similarity:\t\t", cosine_similarity(intra_Group_1[i][0], intra_Group_1[i][1], base = 'word', measure = 'freq'))
    print ("Cosine Distance:\t\t", cosine_distance(intra_Group_1[i][0], intra_Group_1[i][1], base = 'word', measure = 'freq'))
    print ("Jaccard Similarity:\t\t", jaccard_similarity(intra_Group_1[i][0], intra_Group_1[i][1], base = 'word'))
    print ("Jaccard Distance:\t\t", jaccard_distance(intra_Group_1[i][0], intra_Group_1[i][1], base = 'word'))
    print ("Longest Common Subsequence:\t\t", LCS(intra_Group_1[i][0], intra_Group_1[i][1], base = 'word')["size"])
    print ("\n")
    
print("Intra Group (2)\n")
for i in intra_Group_2:
    print("Pair:\t\t\t\t",i)
    intra_Distances["MED_word"] += word_based(intra_Group_2[i][0], intra_Group_2[i][1])["MED"]
    intra_Distances["EUC_word"] += euclidean_distance(intra_Group_2[i][0], intra_Group_2[i][1], base = 'word', measure = 'freq')
    intra_Distances["MAN_word"] += manhattan_distance(intra_Group_2[i][0], intra_Group_2[i][1], base = 'word', measure = 'freq')
    intra_Distances["CHB_word"] += chebychev_distance(intra_Group_2[i][0], intra_Group_2[i][1], base = 'word', measure = 'freq')
    intra_Distances["COS_word"] += cosine_distance(intra_Group_2[i][0], intra_Group_2[i][1], base = 'word', measure = 'freq')
    intra_Distances["JAC_word"] += jaccard_distance(intra_Group_2[i][0], intra_Group_2[i][1], base = 'word')
    intra_Distances["LCS_word"] += LCS(intra_Group_2[i][0], intra_Group_2[i][1], base = "word")["size"]
    
    print ("Minimum Edit Distance:\t\t", word_based(intra_Group_2[i][0], intra_Group_2[i][1])["MED"])
    print ("Euclidean Distance:\t\t", euclidean_distance(intra_Group_2[i][0], intra_Group_2[i][1], base = 'word', measure = 'freq'))
    print ("Manhattan Distance:\t\t", manhattan_distance(intra_Group_2[i][0], intra_Group_2[i][1], base = 'word', measure = 'freq'))
    print ("Chebychev Distance:\t\t", chebychev_distance(intra_Group_2[i][0], intra_Group_2[i][1], base = 'word', measure = 'freq'))
    print ("Cosine Similarity:\t\t", cosine_similarity(intra_Group_2[i][0], intra_Group_2[i][1], base = 'word', measure = 'freq'))
    print ("Cosine Distance:\t\t", cosine_distance(intra_Group_2[i][0], intra_Group_2[i][1], base = 'word', measure = 'freq'))
    print ("Jaccard Similarity:\t\t", jaccard_similarity(intra_Group_2[i][0], intra_Group_2[i][1], base = 'word'))
    print ("Jaccard Distance:\t\t", jaccard_distance(intra_Group_2[i][0], intra_Group_2[i][1], base = 'word'))
    print ("Longest Common Subsequence:\t\t", LCS(intra_Group_2[i][0], intra_Group_2[i][1], base = 'word')["size"])
    print ("\n")
    
print("Intra Group (3)\n")
for i in intra_Group_3:
    print("Pair:\t\t\t\t",i)
    intra_Distances["MED_word"] += word_based(intra_Group_3[i][0], intra_Group_3[i][1])["MED"]
    intra_Distances["EUC_word"] += euclidean_distance(intra_Group_3[i][0], intra_Group_3[i][1], base = 'word', measure = 'freq')
    intra_Distances["MAN_word"] += manhattan_distance(intra_Group_3[i][0], intra_Group_3[i][1], base = 'word', measure = 'freq')
    intra_Distances["CHB_word"] += chebychev_distance(intra_Group_3[i][0], intra_Group_3[i][1], base = 'word', measure = 'freq')
    intra_Distances["COS_word"] += cosine_distance(intra_Group_3[i][0], intra_Group_3[i][1], base = 'word', measure = 'freq')
    intra_Distances["JAC_word"] += jaccard_distance(intra_Group_3[i][0], intra_Group_3[i][1], base = 'word')
    intra_Distances["LCS_word"] += LCS(intra_Group_3[i][0], intra_Group_3[i][1], base = "word")["size"]
    
    print ("Minimum Edit Distance:\t\t", word_based(intra_Group_3[i][0], intra_Group_3[i][1])["MED"])
    print ("Euclidean Distance:\t\t", euclidean_distance(intra_Group_3[i][0], intra_Group_3[i][1], base = 'word', measure = 'freq'))
    print ("Manhattan Distance:\t\t", manhattan_distance(intra_Group_3[i][0], intra_Group_3[i][1], base = 'word', measure = 'freq'))
    print ("Chebychev Distance:\t\t", chebychev_distance(intra_Group_3[i][0], intra_Group_3[i][1], base = 'word', measure = 'freq'))
    print ("Cosine Similarity:\t\t", cosine_similarity(intra_Group_3[i][0], intra_Group_3[i][1], base = 'word', measure = 'freq'))
    print ("Cosine Distance:\t\t", cosine_distance(intra_Group_3[i][0], intra_Group_3[i][1], base = 'word', measure = 'freq'))
    print ("Jaccard Similarity:\t\t", jaccard_similarity(intra_Group_3[i][0], intra_Group_3[i][1], base = 'word'))
    print ("Jaccard Distance:\t\t", jaccard_distance(intra_Group_3[i][0], intra_Group_3[i][1], base = 'word'))
    print ("Longest Common Subsequence:\t\t", LCS(intra_Group_3[i][0], intra_Group_3[i][1], base = 'word')["size"])
    print ("\n")
# Out:
# Intra Group (1)
#
# Pair:				 pair_1
# Minimum Edit Distance:		 4
# Euclidean Distance:		 0.5
# Manhattan Distance:		 1.0
# Chebychev Distance:		 0.25
# Cosine Similarity:		 0.5
# Cosine Distance:		 0.5
# Jaccard Similarity:		 0.3333333333333333
# Jaccard Distance:		 0.6666666666666667
# Longest Common Subsequence:		 2
#
#
# Pair:				 pair_3
# Minimum Edit Distance:		 4
# Euclidean Distance:		 0.6123724356957945
# Manhattan Distance:		 1.0
# Chebychev Distance:		 0.5
# Cosine Similarity:		 0.4082482904638631
# Cosine Distance:		 0.5917517095361369
# Jaccard Similarity:		 0.4
# Jaccard Distance:		 0.6
# Longest Common Subsequence:		 2
#
#
# Pair:				 pair_2
# Minimum Edit Distance:		 4
# Euclidean Distance:		 0.5
# Manhattan Distance:		 1.0
# Chebychev Distance:		 0.25
# Cosine Similarity:		 0.5
# Cosine Distance:		 0.5
# Jaccard Similarity:		 0.3333333333333333
# Jaccard Distance:		 0.6666666666666667
# Longest Common Subsequence:		 2
#
#
# Intra Group (2)
#
# Pair:				 pair_1
# ...

# %% [markdown]
# ## Bigram base
# Jaccard Similarity

# %%
print("Intra Group (1)\n")
for i in intra_Group_1:
    print("Pair:\t\t\t\t",i)
    intra_Distances["JAC_bigram"] += jaccard_distance(intra_Group_1[i][0], intra_Group_1[i][1], base = 'bigram')
    
    print ("Jaccard Similarity:\t\t", jaccard_similarity(intra_Group_1[i][0], intra_Group_1[i][1], base = 'bigram'))
    print ("Jaccard Distance:\t\t", jaccard_distance(intra_Group_1[i][0], intra_Group_1[i][1], base = 'bigram'))
    print ("\n")
    
print("Intra Group (2)\n")
for i in intra_Group_2:
    print("Pair:\t\t\t\t",i)
    intra_Distances["JAC_bigram"] += jaccard_distance(intra_Group_2[i][0], intra_Group_2[i][1], base = 'bigram')
    
    print ("Jaccard Similarity:\t\t", jaccard_similarity(intra_Group_2[i][0], intra_Group_2[i][1], base = 'bigram'))
    print ("Jaccard Distance:\t\t", jaccard_distance(intra_Group_2[i][0], intra_Group_2[i][1], base = 'bigram'))
    print ("\n")
    
    
print("Intra Group (3)\n")
for i in intra_Group_3:
    print("Pair:\t\t\t\t",i)
    intra_Distances["JAC_bigram"] += jaccard_distance(intra_Group_3[i][0], intra_Group_3[i][1], base = 'bigram')
    
    print ("Jaccard Similarity:\t\t", jaccard_similarity(intra_Group_3[i][0], intra_Group_3[i][1], base = 'bigram'))
    print ("Jaccard Distance:\t\t", jaccard_distance(intra_Group_3[i][0], intra_Group_3[i][1], base = 'bigram'))
    print ("\n")
# Out:
# Intra Group (1)
#
# Pair:				 pair_1
# Jaccard Similarity:		 0.5833333333333334
# Jaccard Distance:		 0.41666666666666663
#
#
# Pair:				 pair_3
# Jaccard Similarity:		 0.44
# Jaccard Distance:		 0.56
#
#
# Pair:				 pair_2
# Jaccard Similarity:		 0.46153846153846156
# Jaccard Distance:		 0.5384615384615384
#
#
# Intra Group (2)
#
# Pair:				 pair_1
# Jaccard Similarity:		 0.5416666666666666
# Jaccard Distance:		 0.45833333333333337
#
#
# Pair:				 pair_3
# Jaccard Similarity:		 0.5416666666666666
# Jaccard Distance:		 0.45833333333333337
#
#
# Pair:				 pair_2
# Jaccard Similarity:		 0.6363636363636364
# Jaccard Distance:		 0.36363636363636365
#
#
# Intra Group (3)
#
# Pair:				 pair_1
# Jaccard Similarity:		 0.6086956521739131
# Jaccard Distance:		 0.3913043478260869
#
#
# Pair:				 pair_3
# Jaccard Similarity:		 0.5652173913043478
# Jaccard Distance:		 0.4347826086956522
#
#
# Pair:				 pair_2
# Jaccard Similarity:		 0.44
# Jaccard Distance:		 0.56

# %% [markdown]
# ## Inter-Group

# %%
inter_Group = {
    "pair_1": ["weight 1.3 length 2.7".split(), "weight 6.6 length 6.2".split()],
    "pair_2": ["weight 9.5 length 9.9".split(), "weight 2.3 length 3.1".split()],
    "pair_3": ["weight 6.3 length 5.4".split(), "weight 8.7 length 9.5".split()],
    "pair_4": ["weight 2.0 length 3.1".split(), "weight 6.5 length 6.4".split()],
    "pair_5": ["weight 9.7 length 9.9".split(), "weight 2.5 length 3.8".split()],
    "pair_6": ["weight 6.3 length 5.8".split(), "weight 8.9 length 8.9".split()]
}

# %%
inter_Distances = {}
inter_Distances["MED_char"] = 0
inter_Distances["MED_word"] = 0
inter_Distances["EUC_char"] = 0
inter_Distances["EUC_word"] = 0
inter_Distances["MAN_char"] = 0
inter_Distances["MAN_word"] = 0
inter_Distances["CHB_char"] = 0
inter_Distances["CHB_word"] = 0
inter_Distances["COS_char"] = 0
inter_Distances["COS_word"] = 0
inter_Distances["JAC_char"] = 0
inter_Distances["JAC_word"] = 0
inter_Distances["JAC_bigram"] = 0
inter_Distances["Hamming"] = 0
inter_Distances["LCS_char"] = 0
inter_Distances["LCS_word"] = 0

# %% [markdown]
# ## Char base
# Minimum Edit Distance,
# Euclidean Distance, Manhattan Distance, Chebychev Distance, Cosine Similairty, bigram-level
# Jaccard Similarity, Hamming Distance

# %%
print("Inter Group\n")

for i in inter_Group:
    print("Pair:\t\t\t\t",i)
    inter_Distances["MED_char"] += char_based(inter_Group[i][0], inter_Group[i][1])["total_MED"]
    inter_Distances["EUC_char"] += euclidean_distance(inter_Group[i][0], inter_Group[i][1], base = 'char', measure = 'freq')
    inter_Distances["MAN_char"] += manhattan_distance(inter_Group[i][0], inter_Group[i][1], base = 'char', measure = 'freq')
    inter_Distances["CHB_char"] += chebychev_distance(inter_Group[i][0], inter_Group[i][1], base = 'char', measure = 'freq')
    inter_Distances["COS_char"] += cosine_distance(inter_Group[i][0], inter_Group[i][1], base = 'char', measure = 'freq')
    inter_Distances["JAC_char"] += jaccard_distance(inter_Group[i][0], inter_Group[i][1], base = 'char')
    inter_Distances["Hamming"] += hamming_list_str_dist(inter_Group[i][0], inter_Group[i][1])
    inter_Distances["LCS_char"] += LCS(inter_Group[i][0], inter_Group[i][1], base = 'char')["size"]
    
    print ("Minimum Edit Distance:\t\t", char_based(inter_Group[i][0], inter_Group[i][1])["total_MED"])
    print ("Euclidean Distance:\t\t", euclidean_distance(inter_Group[i][0], inter_Group[i][1], base = 'char', measure = 'freq'))
    print ("Manhattan Distance:\t\t", manhattan_distance(inter_Group[i][0], inter_Group[i][1], base = 'char', measure = 'freq'))
    print ("Chebychev Distance:\t\t", chebychev_distance(inter_Group[i][0], inter_Group[i][1], base = 'char', measure = 'freq'))
    print ("Cosine Similarity:\t\t", cosine_similarity(inter_Group[i][0], inter_Group[i][1], base = 'char', measure = 'freq'))
    print ("Cosine Distance:\t\t", cosine_distance(inter_Group[i][0], inter_Group[i][1], base = 'char', measure = 'freq'))
    print ("Jaccard Similarity:\t\t", jaccard_similarity(inter_Group[i][0], inter_Group[i][1], base = 'char'))
    print ("Jaccard Distance:\t\t", jaccard_distance(inter_Group[i][0], inter_Group[i][1], base = 'char'))
    print ("Hamming Distance:\t\t", hamming_list_str_dist(inter_Group[i][0], inter_Group[i][1]))
    print ("Longest Common Subsequence:\t\t", LCS(inter_Group[i][0], inter_Group[i][1], base = 'char')["size"])
    print ("\n")
# Out:
# Inter Group
#
# Pair:				 pair_1
# Minimum Edit Distance:		 8
# Euclidean Distance:		 0.8660254037844386
# Manhattan Distance:		 1.5
# Chebychev Distance:		 0.75
# Cosine Similarity:		 0.8102546544402054
# Cosine Distance:		 0.1897453455597946
# Jaccard Similarity:		 0.7142857142857143
# Jaccard Distance:		 0.2857142857142857
# Hamming Distance:		 4
# Longest Common Subsequence:		 14
#
#
# Pair:				 pair_4
# Minimum Edit Distance:		 8
# Euclidean Distance:		 0.7905694150420949
# Manhattan Distance:		 2.0
# Chebychev Distance:		 0.5
# Cosine Similarity:		 0.828078671210825
# Cosine Distance:		 0.171921328789175
# Jaccard Similarity:		 0.5625
# Jaccard Distance:		 0.4375
# Hamming Distance:		 4
# Longest Common Subsequence:		 14
#
#
# Pair:				 pair_5
# Minimum Edit Distance:		 8
# Euclidean Distance:		 0.9354143466934853
# Manhattan Distance:		 2.0
# Chebychev Distance:		 0.75
# Cosine Similarity:		 0.7778444682625972
# Cosine Distance:		 0.22215553173740277
# ...

# %% [markdown]
# ## Word base
# Minimum Edit Distance,
# Euclidean Distance, Manhattan Distance, Chebychev Distance, Cosine Similairty, bigram-level
# Jaccard Similarity

# %%
print("Inter Group \n")
for i in inter_Group:
    print("Pair:\t\t\t\t",i)
    inter_Distances["MED_word"] += word_based(inter_Group[i][0], inter_Group[i][1])["MED"]
    inter_Distances["EUC_word"] += euclidean_distance(inter_Group[i][0], inter_Group[i][1], base = 'word', measure = 'freq')
    inter_Distances["MAN_word"] += manhattan_distance(inter_Group[i][0], inter_Group[i][1], base = 'word', measure = 'freq')
    inter_Distances["CHB_word"] += chebychev_distance(inter_Group[i][0], inter_Group[i][1], base = 'word', measure = 'freq')
    inter_Distances["COS_word"] += cosine_distance(inter_Group[i][0], inter_Group[i][1], base = 'word', measure = 'freq')
    inter_Distances["JAC_word"] += jaccard_distance(inter_Group[i][0], inter_Group[i][1], base = 'word')
    inter_Distances["LCS_word"] += LCS(inter_Group[i][0], inter_Group[i][1], base = 'word')["size"]
    
    print ("Minimum Edit Distance:\t\t", word_based(inter_Group[i][0], inter_Group[i][1])["MED"])
    print ("Euclidean Distance:\t\t", euclidean_distance(inter_Group[i][0], inter_Group[i][1], base = 'word', measure = 'freq'))
    print ("Manhattan Distance:\t\t", manhattan_distance(inter_Group[i][0], inter_Group[i][1], base = 'word', measure = 'freq'))
    print ("Chebychev Distance:\t\t", chebychev_distance(inter_Group[i][0], inter_Group[i][1], base = 'word', measure = 'freq'))
    print ("Cosine Similarity:\t\t", cosine_similarity(inter_Group[i][0], inter_Group[i][1], base = 'word', measure = 'freq'))
    print ("Cosine Distance:\t\t", cosine_distance(inter_Group[i][0], inter_Group[i][1], base = 'word', measure = 'freq'))
    print ("Jaccard Similarity:\t\t", jaccard_similarity(inter_Group[i][0], inter_Group[i][1], base = 'word'))
    print ("Jaccard Distance:\t\t", jaccard_distance(inter_Group[i][0], inter_Group[i][1], base = 'word'))
    print ("Longest Common Subsequence:\t\t", LCS(inter_Group[i][0], inter_Group[i][1], base = 'word')["size"])
    print ("\n")
# Out:
# Inter Group
#
# Pair:				 pair_1
# Minimum Edit Distance:		 4
# Euclidean Distance:		 0.5
# Manhattan Distance:		 1.0
# Chebychev Distance:		 0.25
# Cosine Similarity:		 0.5
# Cosine Distance:		 0.5
# Jaccard Similarity:		 0.3333333333333333
# Jaccard Distance:		 0.6666666666666667
# Longest Common Subsequence:		 2
#
#
# Pair:				 pair_4
# Minimum Edit Distance:		 4
# Euclidean Distance:		 0.5
# Manhattan Distance:		 1.0
# Chebychev Distance:		 0.25
# Cosine Similarity:		 0.5
# Cosine Distance:		 0.5
# Jaccard Similarity:		 0.3333333333333333
# Jaccard Distance:		 0.6666666666666667
# Longest Common Subsequence:		 2
#
#
# Pair:				 pair_5
# Minimum Edit Distance:		 4
# Euclidean Distance:		 0.5
# Manhattan Distance:		 1.0
# Chebychev Distance:		 0.25
# Cosine Similarity:		 0.5
# Cosine Distance:		 0.5
# Jaccard Similarity:		 0.3333333333333333
# Jaccard Distance:		 0.6666666666666667
# Longest Common Subsequence:		 2
#
#
# Pair:				 pair_6
# Minimum Edit Distance:		 4
# ...

# %% [markdown]
# ## Bigram base
# Jaccard Similarity

# %%
print("Inter Group\n")
for i in inter_Group:
    print("Pair:\t\t\t\t",i)
    inter_Distances["JAC_bigram"] += jaccard_distance(inter_Group[i][0], inter_Group[i][1], base = 'bigram')
    
    print ("Jaccard Similarity:\t\t", jaccard_similarity(inter_Group[i][0], inter_Group[i][1], base = 'bigram'))
    print ("Jaccard Distance:\t\t", jaccard_distance(inter_Group[i][0], inter_Group[i][1], base = 'bigram'))
    print ("\n")
# Out:
# Inter Group
#
# Pair:				 pair_1
# Jaccard Similarity:		 0.4230769230769231
# Jaccard Distance:		 0.5769230769230769
#
#
# Pair:				 pair_4
# Jaccard Similarity:		 0.4230769230769231
# Jaccard Distance:		 0.5769230769230769
#
#
# Pair:				 pair_5
# Jaccard Similarity:		 0.4230769230769231
# Jaccard Distance:		 0.5769230769230769
#
#
# Pair:				 pair_6
# Jaccard Similarity:		 0.44
# Jaccard Distance:		 0.56
#
#
# Pair:				 pair_3
# Jaccard Similarity:		 0.4074074074074074
# Jaccard Distance:		 0.5925925925925926
#
#
# Pair:				 pair_2
# Jaccard Similarity:		 0.4230769230769231
# Jaccard Distance:		 0.5769230769230769

# %% [markdown]
# # Final Stats

# %% [markdown]
# ## Intra Group

# %%
print("Average Distances on each method for Intra Group:\n")

count = 9
print ("Minimum Edit Distance(char):\t\t", intra_Distances["MED_char"]/count)
print ("Minimum Edit Distance(word):\t\t", intra_Distances["MED_word"]/count)
print ("Euclidean Distance(char):\t\t", intra_Distances["EUC_char"]/count)
print ("Euclidean Distance(word):\t\t", intra_Distances["EUC_word"]/count)
print ("Manhattan Distance(char):\t\t", intra_Distances["MAN_char"]/count)
print ("Manhattan Distance(word):\t\t", intra_Distances["MAN_word"]/count)
print ("Chebychev Distance(char):\t\t", intra_Distances["CHB_char"]/count)
print ("Chebychev Distance(word):\t\t", intra_Distances["CHB_word"]/count)
print ("Cosine Distance(char):\t\t\t", intra_Distances["COS_char"]/count)
print ("Cosine Distance(word):\t\t\t", intra_Distances["COS_word"]/count)
print ("Jaccard Distance(char):\t\t\t", intra_Distances["JAC_char"]/count)
print ("Jaccard Distance(word):\t\t\t", intra_Distances["JAC_word"]/count)
print ("Jaccard Distance(bigram):\t\t", intra_Distances["JAC_bigram"]/count)
print ("Hamming Distance:\t\t\t", intra_Distances["Hamming"]/count)
print ("Longest Common Subsequence(char):\t", intra_Distances["LCS_char"]/count)
print ("Longest Common Subsequence(word):\t", intra_Distances["LCS_word"]/count)
# Out:
# Average Distances on each method for Intra Group:
#
# Minimum Edit Distance(char):		 6.444444444444445
# Minimum Edit Distance(word):		 4.0
# Euclidean Distance(char):		 0.5815214199172708
# Euclidean Distance(word):		 0.5086998068872071
# Manhattan Distance(char):		 1.1111111111111112
# Manhattan Distance(word):		 0.9444444444444444
# Chebychev Distance(char):		 0.3888888888888889
# Chebychev Distance(word):		 0.3055555555555556
# Cosine Distance(char):			 0.09562830987951024
# Cosine Distance(word):			 0.4926114910080304
# Jaccard Distance(char):			 0.21123321123321123
# Jaccard Distance(word):			 0.6222222222222222
# Jaccard Distance(bigram):		 0.4646131324392194
# Hamming Distance:			 3.2222222222222223
# Longest Common Subsequence(char):	 14.777777777777779
# Longest Common Subsequence(word):	 2.0

# %% [markdown]
# ## Inter Group

# %%
print("Average Distances on each method for inter group:\n")

count = 6
print ("Minimum Edit Distance(char):\t\t", inter_Distances["MED_char"]/count)
print ("Minimum Edit Distance(word):\t\t", inter_Distances["MED_word"]/count)
print ("Euclidean Distance(char):\t\t", inter_Distances["EUC_char"]/count)
print ("Euclidean Distance(word):\t\t", inter_Distances["EUC_word"]/count)
print ("Manhattan Distance(char):\t\t", inter_Distances["MAN_char"]/count)
print ("Manhattan Distance(word):\t\t", inter_Distances["MAN_word"]/count)
print ("Chebychev Distance(char):\t\t", inter_Distances["CHB_char"]/count)
print ("Chebychev Distance(word):\t\t", inter_Distances["CHB_word"]/count)
print ("Cosine Distance(char):\t\t\t", inter_Distances["COS_char"]/count)
print ("Cosine Distance(word):\t\t\t", inter_Distances["COS_word"]/count)
print ("Jaccard Distance(char):\t\t\t", inter_Distances["JAC_char"]/count)
print ("Jaccard Distance(word):\t\t\t", inter_Distances["JAC_word"]/count)
print ("Jaccard Distance(bigram):\t\t", inter_Distances["JAC_bigram"]/count)
print ("Hamming Distance:\t\t\t", inter_Distances["Hamming"]/count)
print ("Longest Common Subsequence(char):\t", inter_Distances["LCS_char"]/count)
print ("Longest Common Subsequence(word):\t", inter_Distances["LCS_word"]/count)
# Out:
# Average Distances on each method for inter group:
#
# Minimum Edit Distance(char):		 8.0
# Minimum Edit Distance(word):		 4.0
# Euclidean Distance(char):		 0.8185813970670601
# Euclidean Distance(word):		 0.5187287392826324
# Manhattan Distance(char):		 1.75
# Manhattan Distance(word):		 1.0
# Chebychev Distance(char):		 0.5833333333333334
# Chebychev Distance(word):		 0.2916666666666667
# Cosine Distance(char):			 0.1784828129519452
# Cosine Distance(word):			 0.5152919515893561
# Jaccard Distance(char):			 0.3568452380952381
# Jaccard Distance(word):			 0.6555555555555556
# Jaccard Distance(bigram):		 0.5767141500474833
# Hamming Distance:			 4.0
# Longest Common Subsequence(char):	 14.0
# Longest Common Subsequence(word):	 2.0
