# %%
import codecs

import numpy as np
import glob

# %% [markdown]
# # Reading text file

# %%
file_name = "../data/uniallsentences_train.urdu"

# %%
f_words1 = codecs.open(file_name, "r", "utf-8")
train_data = f_words1.read()

# %%
train_tokens = train_data.split()

# %%
# %run "./allFunctions.ipynb"

# %% [markdown]
# ## Read weights

# %%
if ("../data\\unigram_prob1.0.npz" not in glob.glob("../data/*.npz")):
    print("calculating probs...")
    unigram_prob = calculate_unigram_probs(train_tokens)
    print("probs saving to file '../data/unigram_prob1.0.npz'")
    np.savez("../data/unigram_prob1.0.npz", keys = unigram_prob['keys'], values = unigram_prob['values'])
    print("Probs calculated and saved in file")
else:
    print("Loading file...")
    unigram_prob = np.load("../data/unigram_prob1.0.npz")
    print("file loaded")
# Out:
# Loading file...
# file loaded

# %%
for i in suggest_words_unigram(unigram_prob['values'], unigram_prob['keys'], word_ = 'کا', n = 5):
    print(i)
# Out:
# کا
# کام
# کافی
# کار
# کان

# %% [markdown]
# ## Evaluation

# %%
file_name = "../data/allsentences_test.urdu"

f_words1 = codecs.open(file_name, "r", "utf-8")
test_data = f_words1.read()

# %%
test_data = test_data.split()

# %%
keys_normal = 0
for i in range(0, len(test_data)):
    keys_normal += len(test_data[i])

# %%
keys_normal
# Out:
# 70016

# %%
count_ = 1


for i in range(0, len(test_data)):
    print(i, "--->", test_data[i])
    str_word = ''
    for j in range(0, len(test_data[i])):
        str_word += test_data[i][j]
        
        temps = suggest_words_unigram(unigram_prob['values'], unigram_prob['keys'], word_ = str_word, n = 5)
        
        if (test_data[i] in temps):
            break
        else:
            count_ += 1
# Out:
# 0 ---> نیب
# 1 ---> کی
# 2 ---> جانب
# 3 ---> سے
# 4 ---> گرفتار
# 5 ---> کئے
# 6 ---> گئے
# 7 ---> پنجاب
# 8 ---> یونیورسٹی
# 9 ---> کی
# 10 ---> سابق
# 11 ---> وائس
# 12 ---> چانسلر
# 13 ---> مجاہد
# 14 ---> کامران
# 15 ---> اور
# 16 ---> دوسرے
# 17 ---> پروفیسر
# 18 ---> ہائی
# 19 ---> کورٹ
# 20 ---> سے
# 21 ---> ضمانت
# 22 ---> پر
# 23 ---> رہا
# 24 ---> تو
# 25 ---> ہوگئے
# 26 ---> لیکن
# 27 ---> انہیں
# 28 ---> گرفتار
# 29 ---> کرنے
# 30 ---> کے
# 31 ---> بعد
# 32 ---> ہتھکڑی
# 33 ---> لگا
# 34 ---> کر
# 35 ---> احتساب
# 36 ---> عدالت
# 37 ---> میں
# 38 ---> پیش
# 39 ---> کیا
# 40 ---> گیا
# 41 ---> تو
# 42 ---> ایک
# 43 ---> مسئلہ
# 44 ---> کھڑا
# 45 ---> ہوگیا
# 46 ---> قانون
# 47 ---> کے
# 48 ---> نزدیک
# 49 ---> کوئی
# 50 ---> چھوٹا
# 51 ---> بڑا
# 52 ---> نہیں
# 53 ---> ہوتا
# 54 ---> کوئی
# 55 ---> استاد
# 56 ---> یا
# 57 ---> وزیراعلی
# 58 ---> نہیں
# 59 ---> ہوتا
# 60 ---> جب
# 61 ---> شور
# 62 ---> ہوا
# 63 ---> تو
# 64 ---> ان
# 65 ---> کو
# 66 ---> بھی
# 67 ---> ایک
# ...

# %%
keys_pred = count_

# %%
print("KS = ", (((keys_normal - keys_pred)/keys_normal)*100), "%")
# Out:
# KS =  70.4924588665448 %
